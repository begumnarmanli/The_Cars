# %%
import warnings 
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("The_Cars.csv")

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                     count          mean           std     min      25%  \
# Year              11914.0   2010.384338      7.579740  1990.0   2007.0
# Engine HP         11845.0    249.386070    109.191870    55.0    170.0
# Engine Cylinders  11884.0      5.628829      1.780559     0.0      4.0
# Number of Doors   11908.0      3.436093      0.881315     2.0      2.0
# highway MPG       11914.0     26.637485      8.863001    12.0     22.0
# city mpg          11914.0     19.733255      8.987798     7.0     16.0
# Popularity        11914.0   1554.911197   1441.855347     2.0    549.0
# MSRP              11914.0  40594.737032  60109.103604  2000.0  21000.0
#
#                       50%       75%        max
# Year               2015.0   2016.00     2017.0
# Engine HP           227.0    300.00     1001.0
# Engine Cylinders      6.0      6.00       16.0
# Number of Doors       4.0      4.00        4.0
# highway MPG          26.0     30.00      354.0
# ...

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df["Engine HP"].nunique()
# Out:
# 356

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df=df.drop("Market Category",axis=1)

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.dropna(how='all')
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine Fuel Type      3
# Engine HP            69
# Engine Cylinders     30
# Transmission Type     0
# Driven_Wheels         0
# Number of Doors       6
# Vehicle Size          0
# Vehicle Style         0
# highway MPG           0
# city mpg              0
# Popularity            0
# MSRP                  0
# dtype: int64

# %%
df=df.dropna(how='any')

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
sns.boxplot(data=df, x="Engine HP", color="b")
# Out:
# <Axes: xlabel='Engine HP'>

# %%
sns.boxplot(data=df, x="Engine Cylinders", color="r")
# Out:
# <Axes: xlabel='Engine Cylinders'>

# %%
sns.boxplot(data=df, x="MSRP", color="black")
# Out:
# <Axes: xlabel='MSRP'>

# %%
sns.countplot(data=df, y="Make",color="darksalmon")
# Out:
# <Axes: xlabel='count', ylabel='Make'>

# %%
sns.scatterplot(data=df, x="city mpg", y="highway MPG")
# Out:
# <Axes: xlabel='city mpg', ylabel='highway MPG'>

# %%
df.corr(numeric_only=True)
# Out:
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.337297         -0.026670         0.246173
# Engine HP         0.337297   1.000000          0.788319        -0.128493
# Engine Cylinders -0.026670   0.788319          1.000000        -0.147591
# Number of Doors   0.246173  -0.128493         -0.147591         1.000000
# highway MPG       0.265597  -0.423734         -0.614703         0.116920
# city mpg          0.220053  -0.474810         -0.634460         0.137386
# Popularity        0.086580   0.041418          0.042705        -0.058979
# MSRP              0.209353   0.658983          0.551988        -0.145600
#
#                   highway MPG  city mpg  Popularity      MSRP
# Year                 0.265597  0.220053    0.086580  0.209353
# Engine HP           -0.423734 -0.474810    0.041418  0.658983
# Engine Cylinders    -0.614703 -0.634460    0.042705  0.551988
# Number of Doors      0.116920  0.137386   -0.058979 -0.145600
# ...

# %%
sns.boxplot(data=df, x="city mpg", color="r")
# Out:
# <Axes: xlabel='city mpg'>

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df[df["highway MPG"]>350]
# Out:
#       Make Model  Year                Engine Fuel Type  Engine HP  \
# 1119  Audi    A6  2017  premium unleaded (recommended)      252.0
#
#       Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 1119               4.0  AUTOMATED_MANUAL  front wheel drive              4.0
#
#      Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 1119      Midsize         Sedan          354        24        3105  51600

# %%
df=df[~(df["highway MPG"]>350)]

# %%
df.corr(numeric_only=True)
# Out:
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.337310         -0.026597         0.246136
# Engine HP         0.337310   1.000000          0.788350        -0.128494
# Engine Cylinders -0.026597   0.788350          1.000000        -0.147546
# Number of Doors   0.246136  -0.128494         -0.147546         1.000000
# highway MPG       0.288288  -0.465893         -0.671827         0.125843
# city mpg          0.220010  -0.474820         -0.634439         0.137351
# Popularity        0.086504   0.041422          0.042802        -0.059043
# MSRP              0.209348   0.658984          0.552025        -0.145612
#
#                   highway MPG  city mpg  Popularity      MSRP
# Year                 0.288288  0.220010    0.086504  0.209348
# Engine HP           -0.465893 -0.474820    0.041422  0.658984
# Engine Cylinders    -0.671827 -0.634439    0.042802  0.552025
# Number of Doors      0.125843  0.137351   -0.059043 -0.145612
# ...
